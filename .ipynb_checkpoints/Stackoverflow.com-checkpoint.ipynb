# %%
# !pip install requests-html requests pandas

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.1.2-cp310-cp310-win_amd64.whl.metadata (18 kB)
# Collecting numpy<2,>=1.22.4 (from pandas)
#   Downloading numpy-1.26.1-cp310-cp310-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pcate\onedrive - catesconsultinggroup.com\stackoverflow_app\env\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pcate\onedrive - catesconsultinggroup.com\stackoverflow_app\env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pcate\onedrive - catesconsultinggroup.com\stackoverflow_app\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.2-cp310-cp310-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.7 MB 3.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.7 MB 3.7 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/10.7 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.7 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.7 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.7 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.7 MB 3.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/10.7 MB 2.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/10.7 MB 2.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.7 MB 2.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.7 MB 2.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.5/10.7 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.5/10.7 MB 2.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/10.7 MB 2.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.7/10.7 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.0/10.7 MB 2.6 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/10.7 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.2/10.7 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.5/10.7 MB 2.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/10.7 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.7 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.7 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.2/10.7 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.3/10.7 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.3/10.7 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.5/10.7 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 3.6/10.7 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/10.7 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/10.7 MB 2.7 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.7 MB 2.7 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.7 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 4.1/10.7 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/10.7 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/10.7 MB 2.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.3/10.7 MB 2.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.4/10.7 MB 2.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.4/10.7 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/10.7 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.7 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.7 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.7 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.8/10.7 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.9/10.7 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.7 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 5.1/10.7 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.7 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 5.3/10.7 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.4/10.7 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.7 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.6/10.7 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 5.7/10.7 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 5.7/10.7 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.7 MB 2.3 MB/s eta 0:00:03
#    --------------------- ------------------ 5.9/10.7 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.7 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.7 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.1/10.7 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.2/10.7 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.3/10.7 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.4/10.7 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.5/10.7 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.7 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.8/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.9/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.9/10.7 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.0/10.7 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.7 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.2/10.7 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 7.3/10.7 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 7.4/10.7 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 7.5/10.7 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.7 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.7 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.7/10.7 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.8/10.7 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.8/10.7 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.7 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.0/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 8.2/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 8.3/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.7 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.7 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.6/10.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.8/10.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.0/10.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.0/10.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/10.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.3/10.7 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.7 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.7 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.7 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.7 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.7 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.7 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.4/10.7 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.4/10.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 2.0 MB/s eta 0:00:00
# Downloading numpy-1.26.1-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.8 MB 3.2 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/15.8 MB 2.1 MB/s eta 0:00:08
#     --------------------------------------- 0.2/15.8 MB 2.0 MB/s eta 0:00:08
#     --------------------------------------- 0.4/15.8 MB 2.0 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/15.8 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/15.8 MB 1.9 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/15.8 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.6/15.8 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.7/15.8 MB 1.8 MB/s eta 0:00:09
#    - -------------------------------------- 0.7/15.8 MB 1.8 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/15.8 MB 1.7 MB/s eta 0:00:09
#    -- ------------------------------------- 0.9/15.8 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 0.9/15.8 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/15.8 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.1/15.8 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.2/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.2/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.3/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.4/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.5/15.8 MB 1.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/15.8 MB 1.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.7/15.8 MB 1.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.8/15.8 MB 1.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.9/15.8 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.0/15.8 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/15.8 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.2/15.8 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.2/15.8 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.2/15.8 MB 1.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.3/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.4/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.4/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.5/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.6/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.6/15.8 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.7/15.8 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.8/15.8 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.8/15.8 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.9/15.8 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.9/15.8 MB 1.6 MB/s eta 0:00:08
#    ------- -------------------------------- 3.0/15.8 MB 1.6 MB/s eta 0:00:08
#    ------- -------------------------------- 3.0/15.8 MB 1.6 MB/s eta 0:00:08
#    ------- -------------------------------- 3.1/15.8 MB 1.6 MB/s eta 0:00:08
#    ------- -------------------------------- 3.1/15.8 MB 1.6 MB/s eta 0:00:08
#    -------- ------------------------------- 3.2/15.8 MB 1.6 MB/s eta 0:00:08
#    -------- ------------------------------- 3.2/15.8 MB 1.6 MB/s eta 0:00:09
#    -------- ------------------------------- 3.3/15.8 MB 1.6 MB/s eta 0:00:09
#    -------- ------------------------------- 3.3/15.8 MB 1.5 MB/s eta 0:00:09
#    -------- ------------------------------- 3.3/15.8 MB 1.5 MB/s eta 0:00:09
#    -------- ------------------------------- 3.4/15.8 MB 1.5 MB/s eta 0:00:09
#    -------- ------------------------------- 3.5/15.8 MB 1.5 MB/s eta 0:00:09
#    -------- ------------------------------- 3.5/15.8 MB 1.5 MB/s eta 0:00:09
#    --------- ------------------------------ 3.6/15.8 MB 1.5 MB/s eta 0:00:09
#    --------- ------------------------------ 3.7/15.8 MB 1.5 MB/s eta 0:00:09
#    --------- ------------------------------ 3.7/15.8 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.8/15.8 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.9/15.8 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.9/15.8 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.9/15.8 MB 1.5 MB/s eta 0:00:09
#    ---------- ----------------------------- 4.0/15.8 MB 1.5 MB/s eta 0:00:09
#    ---------- ----------------------------- 4.1/15.8 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.2/15.8 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.2/15.8 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.3/15.8 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.3/15.8 MB 1.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.4/15.8 MB 1.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.4/15.8 MB 1.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.5/15.8 MB 1.4 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.5/15.8 MB 1.4 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.6/15.8 MB 1.4 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.6/15.8 MB 1.4 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.7/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 4.8/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 4.8/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 4.8/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 4.9/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 4.9/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 5.0/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 5.0/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 5.0/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------ --------------------------- 5.1/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.2/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.2/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.2/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.3/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.4/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.4/15.8 MB 1.4 MB/s eta 0:00:08
#    ------------- -------------------------- 5.5/15.8 MB 1.4 MB/s eta 0:00:08
#    -------------- ------------------------- 5.5/15.8 MB 1.4 MB/s eta 0:00:08
#    -------------- ------------------------- 5.6/15.8 MB 1.4 MB/s eta 0:00:08
#    -------------- ------------------------- 5.6/15.8 MB 1.4 MB/s eta 0:00:08
#    -------------- ------------------------- 5.7/15.8 MB 1.3 MB/s eta 0:00:08
#    -------------- ------------------------- 5.7/15.8 MB 1.3 MB/s eta 0:00:08
#    -------------- ------------------------- 5.8/15.8 MB 1.3 MB/s eta 0:00:08
#    -------------- ------------------------- 5.8/15.8 MB 1.3 MB/s eta 0:00:08
#    -------------- ------------------------- 5.9/15.8 MB 1.3 MB/s eta 0:00:08
#    --------------- ------------------------ 6.0/15.8 MB 1.3 MB/s eta 0:00:08
#    --------------- ------------------------ 6.1/15.8 MB 1.4 MB/s eta 0:00:08
#    --------------- ------------------------ 6.2/15.8 MB 1.4 MB/s eta 0:00:08
#    --------------- ------------------------ 6.2/15.8 MB 1.4 MB/s eta 0:00:08
#    --------------- ------------------------ 6.3/15.8 MB 1.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 6.4/15.8 MB 1.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 6.5/15.8 MB 1.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 6.6/15.8 MB 1.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 6.6/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 6.7/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 6.8/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 6.8/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 6.9/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 7.0/15.8 MB 1.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 7.1/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.1/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.2/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.3/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.4/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.4/15.8 MB 1.4 MB/s eta 0:00:07
#    ------------------ --------------------- 7.5/15.8 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 7.6/15.8 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 7.6/15.8 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 7.7/15.8 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 7.8/15.8 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 7.9/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 7.9/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 7.9/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 8.0/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 8.1/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 8.2/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 8.2/15.8 MB 1.4 MB/s eta 0:00:06
#    -------------------- ------------------- 8.3/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.3/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.4/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.4/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.5/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.6/15.8 MB 1.4 MB/s eta 0:00:06
#    --------------------- ------------------ 8.6/15.8 MB 1.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 8.7/15.8 MB 1.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 8.8/15.8 MB 1.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 8.9/15.8 MB 1.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 9.0/15.8 MB 1.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 9.1/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.1/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.3/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.3/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.3/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.4/15.8 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.5/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.5/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.6/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.6/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.7/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.7/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.7/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.8/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 9.9/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 9.9/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.0/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.0/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.1/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.1/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.1/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.2/15.8 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.2/15.8 MB 1.4 MB/s eta 0:00:05
#    -------------------------- ------------- 10.3/15.8 MB 1.4 MB/s eta 0:00:05
#    -------------------------- ------------- 10.4/15.8 MB 1.4 MB/s eta 0:00:05
#    -------------------------- ------------- 10.4/15.8 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 10.5/15.8 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 10.6/15.8 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 10.6/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.7/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.7/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.7/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.8/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.8/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.9/15.8 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 11.0/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.1/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.2/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.2/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.3/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.3/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.4/15.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.4/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.5/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.5/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.6/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.6/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.7/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.8/15.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.8/15.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------ --------- 11.9/15.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------ --------- 11.9/15.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------ --------- 12.0/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/15.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.5/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/15.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.7/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.7/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.8/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.8/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.8/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.9/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.9/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.9/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 13.0/15.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 13.0/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.1/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.2/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.2/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.3/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.3/15.8 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.4/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.4/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.7/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.7/15.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.8/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.8/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.9/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.9/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.0/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.0/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.1/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.1/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.2/15.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.2/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.2/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.3/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.3/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.4/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.5/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.5/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 14.6/15.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 14.6/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.4/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 1.2 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/502.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/502.5 kB ? eta -:--:--
#    -------- ------------------------------- 112.6/502.5 kB 1.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 143.4/502.5 kB 1.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 204.8/502.5 kB 1.1 MB/s eta 0:00:01
#    ------------------ --------------------- 235.5/502.5 kB 1.0 MB/s eta 0:00:01
#    ------------------ --------------------- 235.5/502.5 kB 1.0 MB/s eta 0:00:01
#    --------------------- ---------------- 286.7/502.5 kB 842.9 kB/s eta 0:00:01
#    ------------------------ ------------- 317.4/502.5 kB 819.2 kB/s eta 0:00:01
#    --------------------------- ---------- 358.4/502.5 kB 796.7 kB/s eta 0:00:01
#    --------------------------- ---------- 368.6/502.5 kB 764.2 kB/s eta 0:00:01
#    ------------------------------ ------- 399.4/502.5 kB 778.2 kB/s eta 0:00:01
#    -------------------------------- ----- 430.1/502.5 kB 747.0 kB/s eta 0:00:01
#    ---------------------------------- --- 460.8/502.5 kB 720.9 kB/s eta 0:00:01
#    ------------------------------------ - 481.3/502.5 kB 753.7 kB/s eta 0:00:01
#    -------------------------------------- 502.5/502.5 kB 716.5 kB/s eta 0:00:00
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.26.1 pandas-2.1.2 pytz-2023.3.post1

# %%
import requests
from requests_html import HTML
import time
import pandas as pd

# %%
base_url = "https://stackoverflow.com/questions/tagged/"
tag = "python"
query_filter = "Votes"
url = f"{base_url}{tag}>tab={query_filter}"
url
# Out:
# 'https://stackoverflow.com/questions/tagged/python>tab=Votes'

# %%
print(url)
# Out:
# https://stackoverflow.com/questions/tagged/python>tab=Votes

# %% [raw]
# r = requests.get(url)
# html_str = r.text
# html = HTML(html=html_str)

# %%
#from requests_html import HTML

# %%
#html = HTML(html=html_str)

# %%
question_summaries = html.find(".s-post-summary")
print(question_summaries)
# Out:
# [<Element 'div' id='question-summary-77404125' class=('s-post-summary', 'js-post-summary') data-post-id='77404125' data-post-type-id='1'>, <Element 'div' id='question-summary-77404124' class=('s-post-summary', 'js-post-summary') data-post-id='77404124' data-post-type-id='1'>, <Element 'div' id='question-summary-77404118' class=('s-post-summary', 'js-post-summary') data-post-id='77404118' data-post-type-id='1'>, <Element 'div' id='question-summary-77404114' class=('s-post-summary', 'js-post-summary') data-post-id='77404114' data-post-type-id='1'>, <Element 'div' id='question-summary-77404106' class=('s-post-summary', 'js-post-summary') data-post-id='77404106' data-post-type-id='1'>, <Element 'div' id='question-summary-77404097' class=('s-post-summary', 'js-post-summary') data-post-id='77404097' data-post-type-id='1'>, <Element 'div' id='question-summary-77404044' class=('s-post-summary', 'js-post-summary') data-post-id='77404044' data-post-type-id='1'>, <Element 'div' id='question-summary-77404037' class=('s-post-summary', 'js-post-summary') data-post-id='77404037' data-post-type-id='1'>, <Element 'div' id='question-summary-77404034' class=('s-post-summary', 'js-post-summary') data-post-id='77404034' data-post-type-id='1'>, <Element 'div' id='question-summary-77404032' class=('s-post-summary', 'js-post-summary') data-post-id='77404032' data-post-type-id='1'>, <Element 'div' id='question-summary-77404026' class=('s-post-summary', 'js-post-summary') data-post-id='77404026' data-post-type-id='1'>, <Element 'div' id='question-summary-77403999' class=('s-post-summary', 'js-post-summary') data-post-id='77403999' data-post-type-id='1'>, <Element 'div' id='question-summary-77403973' class=('s-post-summary', 'js-post-summary') data-post-id='77403973' data-post-type-id='1'>, <Element 'div' id='question-summary-77403949' class=('s-post-summary', 'js-post-summary') data-post-id='77403949' data-post-type-id='1'>, <Element 'div' id='question-summary-77403945' class=('s-post-summary', 'js-post-summary') data-post-id='77403945' data-post-type-id='1'>, <Element 'div' id='question-summary-77403942' class=('s-post-summary', 'js-post-summary') data-post-id='77403942' data-post-type-id='1'>, <Element 'div' id='question-summary-77403887' class=('s-post-summary', 'js-post-summary') data-post-id='77403887' data-post-type-id='1'>, <Element 'div' id='question-summary-77403870' class=('s-post-summary', 'js-post-summary') data-post-id='77403870' data-post-type-id='1'>, <Element 'div' id='question-summary-77403855' class=('s-post-summary', 'js-post-summary') data-post-id='77403855' data-post-type-id='1'>, <Element 'div' id='question-summary-77403841' class=('s-post-summary', 'js-post-summary') data-post-id='77403841' data-post-type-id='1'>, <Element 'div' id='question-summary-77403831' class=('s-post-summary', 'js-post-summary') data-post-id='77403831' data-post-type-id='1'>, <Element 'div' id='question-summary-77403829' class=('s-post-summary', 'js-post-summary') data-post-id='77403829' data-post-type-id='1'>, <Element 'div' id='question-summary-77403817' class=('s-post-summary', 'js-post-summary') data-post-id='77403817' data-post-type-id='1'>, <Element 'div' id='question-summary-77403803' class=('s-post-summary', 'js-post-summary') data-post-id='77403803' data-post-type-id='1'>, <Element 'div' id='question-summary-77403801' class=('s-post-summary', 'js-post-summary') data-post-id='77403801' data-post-type-id='1'>, <Element 'div' id='question-summary-77403780' class=('s-post-summary', 'js-post-summary') data-post-id='77403780' data-post-type-id='1'>, <Element 'div' id='question-summary-77403721' class=('s-post-summary', 'js-post-summary') data-post-id='77403721' data-post-type-id='1'>, <Element 'div' id='question-summary-77403712' class=('s-post-summary', 'js-post-summary') data-post-id='77403712' data-post-type-id='1'>, <Element 'div' id='question-summary-77403707' class=('s-post-summary', 'js-post-summary') data-post-id='77403707' data-post-type-id='1' ...

# %%
question_summaries[0].text
# Out:
# "0 votes\n0 answers\n4 views\nScraping form elements in selenium python without specifying class/ID?\nFor other pages I specified the elements, but this pages field is dynamic based on the zip. Is there a way to scrape the values, in the form since they will change? I don't want to have to specify for ...\npython\nselenium-webdriver\nbeautifulsoup\nCodyjane\n1\nasked 2 mins ago"

# %%
question_summaries[1].text
# Out:
# "0 votes\n0 answers\n4 views\nFast evaluation of function of multiple derivatives in sympy\nI have a generic symbolic function x(t) [think of t as time], and a function of various derivatives of x, ie F(x(t),x'(t),x''(t),..., x^(n)(t)). I would like to evaluate F as fast as possible given ...\npython\nsympy\nLance\n125\nasked 2 mins ago"

# %%
columns = ['votes', 'answers', 'views', 'short_description', 'question', 'tag1','tag2', 'tag3','user', 'user-details',  'date']

# %%
this_row = list(question_summaries[0].text.split("\n"))
this_row
# Out:
# ['0 votes',
#  '0 answers',
#  '4 views',
#  'Scraping form elements in selenium python without specifying class/ID?',
#  "For other pages I specified the elements, but this pages field is dynamic based on the zip. Is there a way to scrape the values, in the form since they will change? I don't want to have to specify for ...",
#  'python',
#  'selenium-webdriver',
#  'beautifulsoup',
#  'Codyjane',
#  '1',
#  'asked 2 mins ago']

# %%
#len(this_row) == len(columns)
# Out:
# True

# %%
#row_data = dict(zip(columns, this_row))
#row_data
# Out:
# {'votes': '0 votes',
#  'answers': '0 answers',
#  'views': '4 views',
#  'short_description': 'Scraping form elements in selenium python without specifying class/ID?',
#  'question': "For other pages I specified the elements, but this pages field is dynamic based on the zip. Is there a way to scrape the values, in the form since they will change? I don't want to have to specify for ...",
#  'tag1': 'python',
#  'tag2': 'selenium-webdriver',
#  'tag3': 'beautifulsoup',
#  'user': 'Codyjane',
#  'user-details': '1',
#  'date': 'asked 2 mins ago'}

# %%
#for column, row_v in zip(columns, this_row):
   # print(column, row_v)
# Out:
# votes 0 votes
# answers 0 answers
# views 4 views
# short_description Scraping form elements in selenium python without specifying class/ID?
# question For other pages I specified the elements, but this pages field is dynamic based on the zip. Is there a way to scrape the values, in the form since they will change? I don't want to have to specify for ...
# tag1 python
# tag2 selenium-webdriver
# tag3 beautifulsoup
# user Codyjane
# user-details 1
# date asked 2 mins ago

# %%
key_names = ['question', 'metrics', 'tags']
classes_needed = ['.s-link', '.s-post-summary--stats', '.post-tag']
this_question_element = question_summaries[0]
this_question_element.find('.s-link', first=True).text
this_question_element.find('.s-post-summary--stats', first=True).text.replace('\n', ' ')
# Out:
# '0 votes 0 answers 4 views'

# %%
def clean_scraped_data(text, keyname=None):
    if keyname == 'metrics':
        return text.replace('\n', ' ')
    #if keyname == 'post-tag':
        #return text.replace('\n', ',')
    return text

# %%
datas = []

for q_el in question_summaries:
    question_data = {}
    for i, _class in enumerate(classes_needed):
        sub_el = q_el.find(_class, first=True)
        keyname = key_names[i]
        question_data[keyname] = clean_scraped_data(sub_el.text, keyname=keyname)
    datas.append(question_data)

# %%
def parse_tagged_page(html):
    question_summaries = html.find(".s-post-summary")
    key_names = ['question', 'metrics', 'tags', 'link']
    classes_needed = ['.s-link', '.s-post-summary--stats', '.post-tag', 's-post-summary--content-title']
    datas = []
    for q_el in question_summaries:
        question_data = {}
        for i, _class in enumerate(classes_needed):
            sub_el = q_el.find(_class, first=True)
            keyname = key_names[i]
            question_data[keyname] = clean_scraped_data(sub_el.text, keyname=keyname)
        datas.append(question_data)
    return datas

# %%
def extract_data_from_url(url):
    r = requests.get(url)
    if r.status_code not in range(200, 299):
        return[]
    html_str = r.text
    html = HTML(html=html_str)
    datas = parse_tagged_page(html)
    return datas

# %%
def scrape_tag(tag = "python", query_filter = "Votes", max_pages=50, pagesize=50):
    base_url = "https://stackoverflow.com/questions/tagged/"
    datas = []
    for p in range(max_pages):
        page_num = p + 1
        url = f"{base_url}{tag}?tab={query_filter}&page={page_num}&pagesize={pagesize}"
        datas += extract_data_from_url(url)
        time.sleep(1.2)
    return datas

# %%
datas = scrape_tag(tag='python')
print(datas)
# Out:
# [{'question': 'What does the "yield" keyword do in Python?', 'detail': '12765 votes\n50 answers\n3.3m views', 'tags': 'python'}, {'question': 'What does if __name__ == "__main__": do?', 'detail': '8106 votes\n46 answers\n4.5m views', 'tags': 'python'}, {'question': 'Does Python have a ternary conditional operator?', 'detail': '7824 votes\n32 answers\n2.8m views', 'tags': 'python'}, {'question': 'What are metaclasses in Python?', 'detail': '7307 votes\n25 answers\n1.1m views', 'tags': 'python'}, {'question': 'How do I check whether a file exists without exceptions?', 'detail': '7055 votes\n40 answers\n5.3m views', 'tags': 'python'}, {'question': 'How do I merge two dictionaries in a single expression in Python?', 'detail': '6838 votes\n43 answers\n3.2m views', 'tags': 'python'}, {'question': 'How do I execute a program or call a system command?', 'detail': '6051 votes\n66 answers\n4.5m views', 'tags': 'python'}, {'question': 'How do I create a directory, and any missing parent directories?', 'detail': '5587 votes\n27 answers\n3.6m views', 'tags': 'python'}, {'question': "Accessing the index in 'for' loops", 'detail': '5308 votes\n27 answers\n4.2m views', 'tags': 'python'}, {'question': 'How do I make a flat list out of a list of lists?', 'detail': '5236 votes\n33 answers\n4.1m views', 'tags': 'python'}, {'question': '@staticmethod vs @classmethod in Python', 'detail': '4592 votes\n36 answers\n1.1m views', 'tags': 'python'}, {'question': 'How slicing in Python works', 'detail': '4536 votes\n38 answers\n3.0m views', 'tags': 'python'}, {'question': 'Finding the index of an item in a list', 'detail': '4337 votes\n46 answers\n6.1m views', 'tags': 'python'}, {'question': "Iterating over dictionaries using 'for' loops", 'detail': '4232 votes\n17 answers\n5.7m views', 'tags': 'python'}, {'question': 'How to iterate over rows in a DataFrame in Pandas', 'detail': '3996 votes\n34 answers\n7.0m views', 'tags': 'python'}, {'question': 'Using global variables in a function', 'detail': '3914 votes\n25 answers\n4.0m views', 'tags': 'python'}, {'question': 'How do I get the current time?', 'detail': '3804 votes\n54 answers\n4.2m views', 'tags': 'python'}, {'question': 'Catch multiple exceptions in one line (except block)', 'detail': '3782 votes\n6 answers\n1.4m views', 'tags': 'python'}, {'question': 'How to copy files', 'detail': '3726 votes\n21 answers\n3.5m views', 'tags': 'python'}, {'question': 'Convert bytes to a string in Python 3', 'detail': '3703 votes\n24 answers\n4.9m views', 'tags': 'python'}, {'question': 'What is the difference between __str__ and __repr__?', 'detail': '3654 votes\n28 answers\n962k views', 'tags': 'python'}, {'question': 'What is __init__.py for?', 'detail': '3654 votes\n14 answers\n2.3m views', 'tags': 'python'}, {'question': "Does Python have a string 'contains' substring method?", 'detail': '3587 votes\n10 answers\n6.5m views', 'tags': 'python'}, {'question': 'How can I add new keys to a dictionary?', 'detail': '3491 votes\n21 answers\n5.2m views', 'tags': 'python'}, {'question': 'How do I list all files of a directory?', 'detail': '3466 votes\n21 answers\n7.9m views', 'tags': 'python'}, {'question': 'How do I select rows from a DataFrame based on column values?', 'detail': '3431 votes\n17 answers\n6.1m views', 'tags': 'python'}, {'question': 'How do I sort a dictionary by value?', 'detail': '3414 votes\n34 answers\n5.2m views', 'tags': 'python'}, {'question': '"Least Astonishment" and the Mutable Default Argument', 'detail': '3372 votes\n34 answers\n259k views', 'tags': 'python'}, {'question': 'What does ** (double star/asterisk) and * (star/asterisk) do for parameters?', 'detail': '3338 votes\n28 answers\n1.3m views', 'tags': 'python'}, {'question': 'How can I delete a file or folder in Python?', 'detail': '3308 votes\n17 answers\n3.4m views', 'tags': 'python'}, {'question': 'How do I pass a variable by reference?', 'detail': '3273 votes\n40 answers\n2.0m views', 'tags': 'python'}, {'question': "How do I clon ...

# %%
len(datas)
# Out:
# 50

# %%
df = pd.DataFrame(datas)
df.head()
# Out:
#                                             question  \
# 0  Scraping form elements in selenium python with...
# 1  Fast evaluation of function of multiple deriva...
# 2  how to make auth with react and django in spa app
# 3  I want to start my career as data analyst do y...
# 4  In python, what happens when a thread is start...
#
#                        metrics    tags
# 0    0 votes 0 answers 4 views  python
# 1    0 votes 0 answers 4 views  python
# 2    0 votes 0 answers 5 views  python
# 3  -1 votes 0 answers 15 views  python
# 4    0 votes 0 answers 7 views  python

# %%
df.shape
# Out:
# (50, 3)

# %%
df.to_csv("Python.csv", index=False)

# %%
# could consider adding machine learning with   auto-tagging question bot
